# %% [markdown]
# <a href="https://colab.research.google.com/github/karisrihari/cal/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Create a DataFrame
data = {
    "Id": [1, 2, 3],
    "Name": ["Hari", "Ram", "krishna"],
    "Marks": [85, 90, 88],
    "Roll no ":[500,580,590],
    "Grade ": ["A", "A", "A"]
}
df = pd.DataFrame(data)
plt.bar(df["Name"], df["Marks"])
plt.xlabel("Student Name")
plt.ylabel("Marks")
plt.title("Student Marks")
plt.show()

# %% [markdown]
# import pandas as pd
# df = pd.read_csv("students.csv")
# print(df)

# %%
df.to_csv('students.csv', index=False)
print('DataFrame saved to students.csv')
# Out:
# DataFrame saved to students.csv
